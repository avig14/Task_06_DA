# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Task 06 – SQLite + Python Sales Analysis\n",
    "\n",
    "This notebook demonstrates how to:\n",
    "- Create / connect to an SQLite database\n",
    "- Insert simple sales data into a table\n",
    "- Run an SQL query from Python using `sqlite3`\n",
    "- Load results into a pandas DataFrame\n",
    "- Visualize revenue by product using `matplotlib`.\n",
    "\n",
    "> Designed to work smoothly in VS Code Jupyter environment. The database file `sales_data.db` will be created in the **same folder as this notebook**."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import sqlite3\n",
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "\n",
    "%matplotlib inline"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1. Create / connect to the SQLite database and insert sample data"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# This will create a file named 'sales_data.db' in the same folder as the notebook\n",
    "conn = sqlite3.connect('sales_data.db')\n",
    "cursor = conn.cursor()\n",
    "\n",
    "# Create table (if it does not already exist)\n",
    "cursor.execute('''\n",
    "CREATE TABLE IF NOT EXISTS sales (\n",
    "    product TEXT,\n",
    "    quantity INTEGER,\n",
    "    price REAL\n",
    ");\n",
    "''')\n",
    "\n",
    "# Optional: clear old data for repeatable runs\n",
    "cursor.execute('DELETE FROM sales')\n",
    "\n",
    "# Insert sample rows\n",
    "sample_data = [\n",
    "    ('Milk', 10, 30),\n",
    "    ('Bread', 5, 20),\n",
    "    ('Eggs', 12, 12),\n",
    "    ('Butter', 4, 50),\n",
    "    ('Cheese', 6, 40),\n",
    "]\n",
    "\n",
    "cursor.executemany('INSERT INTO sales VALUES (?, ?, ?)', sample_data)\n",
    "conn.commit()\n",
    "print('Inserted sample data into sales table.')"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2. Query the database and load results into pandas"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "query = '''\n",
    "SELECT \n",
    "    product,\n",
    "    SUM(quantity) AS total_quantity,\n",
    "    SUM(quantity * price) AS total_revenue\n",
    "FROM sales\n",
    "GROUP BY product\n",
    "ORDER BY total_revenue DESC;\n",
    "'''\n",
    "\n",
    "df = pd.read_sql_query(query, conn)\n",
    "print('Sales summary:')\n",
    "df"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 3. Visualize revenue by product"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "plt.figure(figsize=(8,5))\n",
    "plt.bar(df['product'], df['total_revenue'], color='skyblue')\n",
    "plt.title('Revenue by Product')\n",
    "plt.xlabel('Product')\n",
    "plt.ylabel('Revenue (₹)')\n",
    "plt.grid(axis='y', linestyle='--', alpha=0.5)\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 4. Close the database connection"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "conn.close()\n",
    "print('Connection closed.')"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.x"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 21
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# Task 06 – SQLite + Python Sales Analysis\n",
#       8     "\n",
#       9     "This notebook demonstrates how to:\n",
#      10     "- Create / connect to an SQLite database\n",
#      11     "- Insert simple sales data into a table\n",
#      12     "- Run an SQL query from Python using `sqlite3`\n",
#      13     "- Load results into a pandas DataFrame\n",
#      14     "- Visualize revenue by product using `matplotlib`.\n",
#      15     "\n",
#      16     "> Designed to work smoothly in VS Code Jupyter environment. The database file `sales_data.db` will be created in the **same folder as this notebook**."
#      17    ]
#      18   },
#      19   {
#      20    "cell_type": "code",
# ---> 21    "execution_count": null,
#      22    "metadata": {},
#      23    "outputs": [],
#      24    "source": [
#      25     "import sqlite3\n",
#      26     "import pandas as pd\n",
#      27     "import matplotlib.pyplot as plt\n",
#      28     "\n",
#      29     "%matplotlib inline"
#      30    ]
#      31   },
#      32   {
#      33    "cell_type": "markdown",
#      34    "metadata": {},
#      35    "source": [
#      36     "## 1. Create / connect to the SQLite database and insert sample data"
#      37    ]
#      38   },
#      39   {
#      40    "cell_type": "code",
#      41    "execution_count": null,
#      42    "metadata": {},
#      43    "outputs": [],
#      44    "source": [
#      45     "# This will create a file named 'sales_data.db' in the same folder as the notebook\n",
#      46     "conn = sqlite3.connect('sales_data.db')\n",
#      47     "cursor = conn.cursor()\n",
#      48     "\n",
#      49     "# Create table (if it does not already exist)\n",
#      50     "cursor.execute('''\n",
#      51     "CREATE TABLE IF NOT EXISTS sales (\n",
#      52     "    product TEXT,\n",
#      53     "    quantity INTEGER,\n",
#      54     "    price REAL\n",
#      55     ");\n",
#      56     "''')\n",
#      57     "\n",
#      58     "# Optional: clear old data for repeatable runs\n",
#      59     "cursor.execute('DELETE FROM sales')\n",
#      60     "\n",
#      61     "# Insert sample rows\n",
#      62     "sample_data = [\n",
#      63     "    ('Milk', 10, 30),\n",
#      64     "    ('Bread', 5, 20),\n",
#      65     "    ('Eggs', 12, 12),\n",
#      66     "    ('Butter', 4, 50),\n",
#      67     "    ('Cheese', 6, 40),\n",
#      68     "]\n",
#      69     "\n",
#      70     "cursor.executemany('INSERT INTO sales VALUES (?, ?, ?)', sample_data)\n",
#      71     "conn.commit()\n",
#      72     "print('Inserted sample data into sales table.')"
#      73    ]
#      74   },
#      75   {
#      76    "cell_type": "markdown",
#      77    "metadata": {},
#      78    "source": [
#      79     "## 2. Query the database and load results into pandas"
#      80    ]
#      81   },
#      82   {
#      83    "cell_type": "code",
#      84    "execution_count": null,
#      85    "metadata": {},
#      86    "outputs": [],
#      87    "source": [
#      88     "query = '''\n",
#      89     "SELECT \n",
#      90     "    product,\n",
#      91     "    SUM(quantity) AS total_quantity,\n",
#      92     "    SUM(quantity * price) AS total_revenue\n",
#      93     "FROM sales\n",
#      94     "GROUP BY product\n",
#      95     "ORDER BY total_revenue DESC;\n",
#      96     "'''\n",
#      97     "\n",
#      98     "df = pd.read_sql_query(query, conn)\n",
#      99     "print('Sales summary:')\n",
#     100     "df"
#     101    ]
#     102   },
#     103   {
#     104    "cell_type": "markdown",
#     105    "metadata": {},
#     106    "source": [
#     107     "## 3. Visualize revenue by product"
#     108    ]
#     109   },
#     110   {
#     111    "cell_type": "code",
#     112    "execution_count": null,
#     113    "metadata": {},
#     114    "outputs": [],
#     115    "source": [
#     116     "plt.figure(figsize=(8,5))\n",
#     117     "plt.bar(df['product'], df['total_revenue'], color='skyblue')\n",
#     118     "plt.title('Revenue by Product')\n",
#     119     "plt.xlabel('Product')\n",
#     120     "plt.ylabel('Revenue (₹)')\n",
#     121     "plt.grid(axis='y', linestyle='--', alpha=0.5)\n",
#     122     "plt.show()"
#     123    ]
#     124   },
#     125   {
#     126    "cell_type": "markdown",
#     127    "metadata": {},
#     128    "source": [
#     129     "## 4. Close the database connection"
#     130    ]
#     131   },
#     132   {
#     133    "cell_type": "code",
#     134    "execution_count": null,
#     135    "metadata": {},
#     136    "outputs": [],
#     137    "source": [
#     138     "conn.close()\n",
#     139     "print('Connection closed.')"
#     140    ]
#     141   }
#     142  ],
#     143  "metadata": {
#     144   "kernelspec": {
#     145    "display_name": "Python 3",
#     146    "language": "python",
#     147    "name": "python3"
#     148   },
#     149   "language_info": {
#     150    "name": "python",
#     151    "version": "3.x"
#     152   }
#     153  },
#     154  "nbformat": 4,
#     155  "nbformat_minor": 5
#     156 }
#
# NameError: name 'null' is not defined
